# %%
import pandas as pd

# %%
df = pd.read_csv("updatedempinfo.csv")

# %%
#no. or rows and columns
df.shape

# %%
# display column name
df.columns

# %%
# display first 5 records
df.head(8)

# %%
# display last 5 records
df.tail(5)

# %%
# display dtypes
df.dtypes

# %%
df.info()

# %%
#df.iloc[rows,columns]
df.iloc[5:8]

#df.iloc[5:8,5:10]
#df.iloc[:,5:7]["occupation"]

# %%
# display one column
df["workclass"]

# %%
# dsiplay multiple columns
df[["workclass","education","age"]]

# %%
df[["workclass","education","age"]].to_csv("3columns.csv")

# %%
df.head(22).to_csv("22rows.csv")

# %%
df['workclass']

# %%
df['workclass'].unique()  # distince items in the column

# %%
df['workclass'].nunique()

# %%
df['gender'].value_counts()

# %%
df.all()

# %%
df

# %%
# one condition
cond = df['workclass'] == " Private"
df[cond]

# %%
# one condition
cond = df['workclass'].str.strip() == "Private"
df[cond]

# %%
df.query("workclass == ' Private'")

# %%
# multiple conditions
cond1 = df['workclass'] == " Private"
cond2 = df['gender'] == " Male"

df[cond1 & cond2]

# %%
df.query("  workclass == ' Private' and gender == ' Male'  ")

# %%
df.shape

# %%
df.drop_duplicates()

# %%
df.sort_values('age')

# %%
df.sort_values('age', ascending= False)

# %%
df

# %%
df.dropna()  # drop null values

# %%
df.fillna(0)   # replace missing values with 0

# %%
df.isnull().sum()

# %%
df.drop(columns = ["workclass","education","gender"])

# %%
df.drop([1,3])   # 1st and 3rd rows
# Out:
#        age      workclass  fnlwgt    education  educational-num  \
# 0       39      State-gov   77516    Bachelors               13
# 2       38        Private  215646      HS-grad                9
# 4       28        Private  338409    Bachelors               13
# 5       37        Private  284582      Masters               14
# 6       49        Private  160187          9th                5
# ...    ...            ...     ...          ...              ...
# 32556   27        Private  257302   Assoc-acdm               12
# 32557   40        Private  154374      HS-grad                9
# 32558   58        Private  151910      HS-grad                9
# 32559   22        Private  201490      HS-grad                9
# 32560   52   Self-emp-inc  287927      HS-grad                9
#
#                marital-status          occupation    relationship    race  \
# 0               Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
cond = df['age'] <85
df.drop(  df[cond].index  )
# Out:
#        age          workclass  fnlwgt      education  educational-num  \
# 222     90            Private   51744        HS-grad                9
# 1040    90            Private  137018        HS-grad                9
# 1168    88   Self-emp-not-inc  206291    Prof-school               15
# 1935    90            Private  221832      Bachelors               13
# 2303    90            Private   52386   Some-college               10
# 2891    90            Private  171956   Some-college               10
# 4070    90            Private  313986           11th                7
# 4109    90                  ?  256514      Bachelors               13
# 5104    90            Private   52386   Some-college               10
# 5272    90            Private  141758            9th                5
# 5370    90          Local-gov  227796        Masters               14
# 5406    90            Private   51744        Masters               14
# ...
